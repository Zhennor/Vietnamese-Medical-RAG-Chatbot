# %%
# !git clone https://github.com/Zhennor/Vietnamese-Medical-RAG-Chatbot
# %cd Vietnamese-Medical-RAG-Chatbot

# %%
# !pip install pyngrok
# !pip install -r requirements.txt

# %%
# !ngrok authtoken 2s5UGTLCkQWBkLWF8Ma6iAyFAx4_3XgqdveqoCDby3eqsqKoe
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip -o ngrok-stable-linux-amd64.zip

from pyngrok import ngrok

public_url = ngrok.connect(8501)
get_ipython().system_raw('!streamlit run /kaggle/working/Vietnamese-Medical-RAG-Chatbot/run_app.py &')
public_url

# %%
# !streamlit run run_app.py --server.runOnSave=false
